# %% [markdown]
# <a href="https://colab.research.google.com/github/Sankalp9993/UBBA-204-214529/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
s = pd.Series([1,3,5,np. nan,6,8])
print (s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101 ', periods=6)
print (dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,3), index=dates, columns=list('ABD'))
df
# Out:
#                    A         B         D
# 2013-01-01  1.067043  0.887519  1.041422
# 2013-01-02  1.759438  0.702548 -0.248499
# 2013-01-03 -0.901648  1.002397  0.334519
# 2013-01-04  0.354305 -0.665491  2.033663
# 2013-01-05 -0.613713 -0.222655 -2.454923
# 2013-01-06 -0.156892 -0.979820  0.428335

# %%
df2 = pd.DataFrame({ ' A ' : 1.,
 ' B  ': pd.Timestamp('  20130102  '),
 ' C  ': pd.Series(1,index=list(range(4))),
 ' D ': np.array([3] * 4),
 ' E  ': pd.Categorical([" test "," train "," test "," train "]),
 ' F  ': ' foo'  })
df2
# Out:
#     A         B     C     D       E     F
# 0  1.0 2013-01-02     1    3    test    foo
# 1  1.0 2013-01-02     1    3   train    foo
# 2  1.0 2013-01-02     1    3    test    foo
# 3  1.0 2013-01-02     1    3   train    foo

# %%
df2.dtypes
# Out:
#  A             float64
#  B      datetime64[ns]
#  C               int64
#  D               int64
#  E            category
#  F              object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         D
# 2013-01-01  1.067043  0.887519  1.041422
# 2013-01-02  1.759438  0.702548 -0.248499
# 2013-01-03 -0.901648  1.002397  0.334519
# 2013-01-04  0.354305 -0.665491  2.033663
# 2013-01-05 -0.613713 -0.222655 -2.454923

# %%
df.describe()
# Out:
#               A         B         D
# count  6.000000  6.000000  6.000000
# mean   0.251422  0.120750  0.189086
# std    1.019283  0.854527  1.509278
# min   -0.901648 -0.979820 -2.454923
# 25%   -0.499508 -0.554782 -0.102745
# 50%    0.098706  0.239947  0.381427
# 75%    0.888858  0.841277  0.888150
# max    1.759438  1.002397  2.033663

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.067043    1.759438   -0.901648    0.354305   -0.613713   -0.156892
# B    0.887519    0.702548    1.002397   -0.665491   -0.222655   -0.979820
# D    1.041422   -0.248499    0.334519    2.033663   -2.454923    0.428335

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#                    A         B         D
# 2013-01-01  1.067043  0.887519  1.041422
# 2013-01-02  1.759438  0.702548 -0.248499
# 2013-01-03 -0.901648  1.002397  0.334519
# 2013-01-04  0.354305 -0.665491  2.033663
# 2013-01-05 -0.613713 -0.222655 -2.454923
# 2013-01-06 -0.156892 -0.979820  0.428335

# %%
df.loc[dates[3]]
# Out:
# A    0.354305
# B   -0.665491
# D    2.033663
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.at[dates[1],'B']
# Out:
# 0.7025482817171117

# %%
df.iloc[3]
# Out:
# A    0.354305
# B   -0.665491
# D    2.033663
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iat[1,1]
# Out:
# 0.7025482817171117

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-edb969d5a66a> in <module>()
# ----> 1 pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     104         margins_name,
#     105         observed,
# --> 106         sort,
#     107     )
#     108     return table.__finalize__(data, method="pivot_table")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     162         values = list(values)
#     163
# --> 164     grouped = data.groupby(keys, observed=observed, sort=sort)
#     165     agged = grouped.agg(aggfunc)
# ...
