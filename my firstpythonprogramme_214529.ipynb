# %%
print('sai ram')
print('sai')
print ("ram")
a =69
print (a)
# Out:
# sai ram
# sai
# ram
# 69

# %%
print("Hello, World")
if 5 > 2 :
  print("five is greater than two")
  if 3 > 2 :
    print("nine is greater than two ")
  else :
    print ("wrong")
# Out:
# Hello, World
# five is greater than two
# nine is greater than two

# %%
print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
a = type (8)
print (a)
type (6.33)
# Out:
# <class 'int'>
# float

# %%
float (9)
# Out:
# 9.0

# %%
str(1)
# Out:
# '1'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
bool (0)
# Out:
# False

# %%
int(False)
# Out:
# 0

# %%
float(True)
# Out:
# 1.0

# %%
a = 8//3
print("coficient is", a)
# Out:
# coficient is 2

# %%
p = 8%3
print (p)
# Out:
# 2

# %%
a = type (99)
print (a)
type (9.3)
# Out:
# <class 'int'>
# float

# %%
int(False)
# Out:
# 0

# %%
name = "Sankalp"
print (name[2])
# Out:
# n

# %%
print (name[-5])
# Out:
# n

# %%
len ('Sankalp')
# Out:
# 7

# %%
name[0:4]
# Out:
# 'Sank'

# %%
name[::2]
# Out:
# 'Snap'

# %%
name[0:5:3]
# Out:
# 'Sk'

# %%
print (name +    "singh")
# Out:
# Sankalpsingh

# %%
b = 54
h = 16
area = 1/2*b*h
print (area)
# Out:
# 432.0

# %%
name1 = " Earth revolves around the sun "
print (name1 [6:15])
# Out:
#  revolves

# %%
name1 [-4:-1]
# Out:
# 'sun'

# %%
name2 = " I love watching "
name3 = " Documentries "
name4 = " movies "
print (name2 + name3 + "and" + name4)
# Out:
#  I love watching  Documentries and movies

# %%
num = " 2 "
print (name2 + num + name4 + " everyweek ")
# Out:
#  I love watching  2  movies  everyweek

# %%
p = float (input ('p =  '))
t = float (input ('t =  '))
r = float (input ('r =  '))
ptr = ((t - p)* 100 ) / (p* r)
print (ptr)
# Out:
# p =  4
# t =  10
# r =  50
# 3.0

# %%
cost = 5
paid = 10
returns = (paid -cost)
print (returns)
# Out:
# 5

# %%
r = float(input('R = '))
t1 = float(input('Larger Time = '))
t2 = float(input('Shorter Time = '))
dif = float(input('Difference between interests '))

si1 = (p*r*t1)/100
si2 = (p*r*t2)/100
p = (dif / r * (t2 - t1)) * 100
print (p)
# Out:
# R = 10
# Larger Time = 7
# Shorter Time = 6
# Difference between interests 650
# -6500.0

# %%
if 9 > 10  :
  print ("the first number is greater than the second one")
else :
  print ("the second number is greater than the first one")
# Out:
# the second number is greater than the first one

# %%
#Nested conditions 
x=10
y=10
if x == y :
  print ("both the numbers are equal")
if 9 > 10  :
  print ("the first number is greater than the second one")
else :
  print ("the second number is greater than the first one")
# Out:
# both the numbers are equal
# the second number is greater than the first one

# %%
if 1 > 0 :
  print (1+1)

# %%
# Marks are grade; Below 40 = Fail, Above 40 and below 80 = B, Above 80 = A 
x= 78
if x < 40 :
 print ("Fail")
if 40 <= x <= 80 :
  print (" Grade B ")
if 80 < x <= 100 :
  print (" Grade A ")
if x > 100 :
  print (" Wrong Computation ")
# Out:
#  Grade B

# %%
#srajan 
Year = float (input('year = '))
if Year < 1752 :
  print("Invalid")
elif (Year % 4) == 0 :
  print("is a leapyear")
else :
  print("not a leapyear")
# Out:
# year = 2008
# is a leapyear

# %%
#exercise to find the given year is Leap Year or not 
year = int(input("Enter Year: "))
if year % 4 == 0 and year % 100 != 0:
    print(year, "is a Leap Year")
elif year % 100 == 0:
    print(year, "is not a Leap Year")
elif year % 400 ==0:
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# Enter Year: 2030
# 2030 is not a Leap Year

# %%
#exercise to find the given year is Leap Year or not 
year = int(input("Please Enter the Year Number you wish: "))

if(year%4 == 0):
    if(year%100 == 0):
        if(year%400 == 0):
            print("%d is a Leap Year" %year)
        else:
            print("%d is Not the Leap Year" %year)
    else:
        print("%d is a Leap Year" %year)
else:
    print("%d is Not the Leap Year" %year)
# Out:
# Please Enter the Year Number you wish: 1200
# 1200 is a Leap Year

# %%
                                                                  #CIE-1
#Exercise 1: Write a program that uses input to prompt 
name = input('Enter your name:')
print('Hello'); print(name)
# Out:
# Enter your name:Sankalp
# Hello
# Sankalp

# %%
#Exercise 2: Write a program to prompt the user for hours and rate per hour to compute gross pay.Enter Hours: 48 Enter Rate: 3.5 Pay: 168.0
hours = float(input('Enter Hours:'))
rate = float(input('Enter Rate:'))
pay = hours * rate
print ('Pay ='), pay
# Out:
# Enter Hours:48
# Enter Rate:3.5
# Pay =
# (None, 168.0)

# %%
#Exercise 3: Assume that we execute the following assignment statements:
#width = 24
#height = 15.0


width = float(input("Enter the Width: "))
height = float(input("Enter the Height: "))


print("Value is : ", width // 2, "and type is: " ,type(width // 2))
print("Value is : ", width / 2.0 ,"and type is: " , type(width / 2.0))
print("Value is : ", width / 3 ,"and type is: " , type(width / 3))
print("Value is :" , 1 + 2 * 5,"and type is: " , type(1 + 2 * 5))
# Out:
# Enter the Width: 24
# Enter the Height: 15
# Value is :  12.0 and type is:  <class 'float'>
# Value is :  12.0 and type is:  <class 'float'>
# Value is :  8.0 and type is:  <class 'float'>
# Value is : 11 and type is:  <class 'int'>

# %%
#Exercise 4: A Celsius temperature, convert the temperature to Fahrenheit, and print out the Result Write a program which prompts the user f

temp1 = float(input('Enter temperature in celsius here'))
temp2 = 1.8 * temp1 + 32
print(temp2)
# Out:
# Enter temperature in celsius here32
# 89.6

# %%
#Exercise 5: Rewrite your pay computation to give the employee 1.5 times the hourly rate for hours worked above 40 hours.
#Enter Hours: 44
#Enter Rate: 7
#Pay: 322.0

hours = float(input('Enter Hours:'))
rate = float(input('Enter Rate:'))

if hours <= 40:
  pay = hours * rate
else: 
  pay = ((hours - 40) * (1.5 * rate)) + (40 * rate)

print ('Pay ='), pay
# Out:
# Enter Hours:44
# Enter Rate:7
# Pay =
# (None, 322.0)

# %%
#Exercise 6: Rewrite your pay program using try and except so that your program handles non-numeric input gracefully by printing a message
#and exiting the program. The following shows two executions of the program:
#Enter Hours: 32
#Enter Rate: twelve 
#Error, please enter numeric input
#Enter Hours: forty
#Error, please enter numeric input


h = input('Enter Hours:')
r = input('Enter Rate:')

try:
  hours = float(h)
  rate = float (r)
  if hours <= 40:
    pay = hours * rate
  else:
    pay = ((hours - 40) * (1.5 * rate)) + (40 * rate)
  print ('Pay ='), pay
except:
    print('Error, please enter numeric input')
# Out:
# Enter Hours:32
# Enter Rate:twelve
# Error, please enter numeric input

# %%
#Exercise 7: Write a program to prompt for a score between 0.0 and 1.0. If the score is out of range, print an error message. If the score is
#between 0.0 and 1.0, print a grade using the following table: 
#Score Grade  #>= 0.9 A
              #>= 0.8 B
              #>= 0.7 C
              #>= 0.6 D
              #< 0.6 F

score = input("Enter Score: ")
s =  float(score)
x = 'Error'
if s >= 0.9:
	x = 'A'
elif s >=0.8:
	x='B'
elif s >=0.7:
	x='C'
elif s >= 0.6:
	x='D'
elif s < .6:
	x ='F'
else:
	x ="Out of Range"
print (x)
# Out:
# Enter Score: 0.62
# D

# %%
#Exercise 8 :# Python program to check if year is a leap year or not
year = int(input("Please Enter the Year Number you wish: "))

if (( year%400 == 0)or (( year%4 == 0 ) and ( year%100 != 0))):
    print("%d is a Leap Year" %year)
else:
    print("%d is Not the Leap Year" %year)
# Out:
# Please Enter the Year Number you wish: 2022
# 2022 is Not the Leap Year

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6
